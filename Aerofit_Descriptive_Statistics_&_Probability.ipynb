# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravRana24/Aerofit_EDA_prob_n_stats/blob/main/Aerofit_Descriptive_Statistics_%26_Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Import the dataset and do usual data analysis steps**

# %%
data=pd.read_csv("aerofit_treadmill.csv")

# %%
# top 5 rows from above
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
# 5 rows from below
data.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   KP781   40   Male         21        Single      6        5   83416
# 176   KP781   42   Male         18        Single      5        4   89641
# 177   KP781   45   Male         16        Single      5        5   90886
# 178   KP781   47   Male         18     Partnered      4        5  104581
# 179   KP781   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
# check data type of all columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# find the number of rows and columns
data.shape
# Out:
# (180, 9)

# %%
# check missing value in all columns
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# **There is no missing values in the data.**

# %%
data.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
data["Product"].value_counts()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
Total_Products=data["Product"].value_counts().sum()
Total_Products
# Out:
# 180

# %%
KP781=data[data["Product"]=="KP781"]["Product"].count()
KP481=data[data["Product"]=="KP481"]["Product"].count()
KP281=data[data["Product"]=="KP281"]["Product"].count()

# %%
KP781/Total_Products*100
# Out:
# 22.22222222222222

# %%
KP481/Total_Products*100
# Out:
# 33.33333333333333

# %%
KP281/Total_Products*100
# Out:
# 44.44444444444444

# %% [markdown]
# **44% sales by KP281 ,33% sales by KP481 22% sales by KP781**

# %% [markdown]
# # **Detect Outliers**

# %%
# checking outliers using boxplot
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.boxplot(data,x="Age")
plt.subplot(2,3,2)
sns.boxplot(data,x="Education")
plt.subplot(2,3,3)
sns.boxplot(data,x="Usage")
plt.subplot(2,3,4)
sns.boxplot(data,x="Fitness")
plt.subplot(2,3,5)
sns.boxplot(data,x="Income")
plt.subplot(2,3,6)
sns.boxplot(data,x="Miles")
plt.show()

# %% [markdown]
# **Income and Miles have most of outliers rest all data has minimum outliers**

# %% [markdown]
# # **Check relationship of categorical/numerical columns with product column**

# %%
'''# analysis of numeric columns
    1. Age
    2. Education
    3. usage
    4. fitness
    5. income
    6. miles'''

'''# analysis of category columns
    1. product
    2. gender
    3. maritalstatus'''
# Out:
# '# analysis of category columns\n    1. product\n    2. gender\n    3. maritalstatus'

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
# univariate analysis of all numeric columns
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.histplot(data,x="Age",kde=True)
plt.subplot(2,3,2)
sns.histplot(data,x="Education",kde=True)
plt.subplot(2,3,3)
sns.histplot(data,x="Usage",kde=True)
plt.subplot(2,3,4)
sns.histplot(data,x="Fitness",kde=True)
plt.subplot(2,3,5)
sns.histplot(data,x="Income",kde=True)
plt.subplot(2,3,6)
sns.histplot(data,x="Miles",kde=True)
plt.show()

# %% [markdown]
# Majority of the product is purchased in the age group of 24 to 34
#
# Majority of the people having total education of 16 years are buying this product
#
# People mostly use this product 3 to 4 days in a week
#
# According to the data average fitness rating of the people is 3
#
# mostly people are from 40000 to 60000 income age group
#
# MAJORITY of the people runs/walks less than 100 miles in a week

# %%
# univariate analysis of all category columns
plt.figure(figsize=(20, 8))
plt.subplot(1,3,1)
sns.countplot(data,x="Product")
plt.subplot(1,3,2)
sns.countplot(data,x="Gender")
plt.subplot(1,3,3)
sns.countplot(data,x="MaritalStatus")
plt.show()

# %% [markdown]
# * KP281 is the most purchased product.
# * There are more males buying the product over females.
# * More Partnered persons are there in the data.

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
# bivariate analysis of all numeric columns with product column
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.boxplot(data,x="Product",y="Age")
plt.subplot(2,3,2)
sns.boxplot(data,x="Product",y="Education")
plt.subplot(2,3,3)
sns.boxplot(data,x="Product",y="Usage")
plt.subplot(2,3,4)
sns.boxplot(data,x="Product",y="Fitness")
plt.subplot(2,3,5)
sns.boxplot(data,x="Product",y="Income")
plt.subplot(2,3,6)
sns.boxplot(data,x="Product",y="Miles")
plt.show()

# %% [markdown]
# majority of the data lies 24 to 34 age group and 40000 to 55000 income
#
# product kp281 and kp481 most buyer have 14 to 16 years of education and People with education above 16 tends to buy KP781
#
# People who are using the product more then 4 days a week have highest possibility that the product is KP781
#
# People with fitness more then 4 are using KP781
#
# People running or walking over 120 miles per week are using KP781

# %%
# bivariate analysis of all numeric columns with gender column
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.boxplot(data,x="Gender",y="Age")
plt.subplot(2,3,2)
sns.boxplot(data,x="Gender",y="Education")
plt.subplot(2,3,3)
sns.boxplot(data,x="Gender",y="Usage")
plt.subplot(2,3,4)
sns.boxplot(data,x="Gender",y="Fitness")
plt.subplot(2,3,5)
sns.boxplot(data,x="Gender",y="Income")
plt.subplot(2,3,6)
sns.boxplot(data,x="Gender",y="Miles")
plt.show()

# %% [markdown]
# majroity of data for both male and female are from 24 to 34 age and there education years between 14 to 16
#
# male usage of treadmill are more than female  and there fitness level is also high as compare to female
#
#
# majority of male income between 45000 to 60000 and variablity in male income is more as compare to female
#
# male runs/walks more than the female

# %%
# bivariate analysis of all numeric columns with marital status column
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.boxplot(data,x="MaritalStatus",y="Age")
plt.subplot(2,3,2)
sns.boxplot(data,x="MaritalStatus",y="Education")
plt.subplot(2,3,3)
sns.boxplot(data,x="MaritalStatus",y="Usage")
plt.subplot(2,3,4)
sns.boxplot(data,x="MaritalStatus",y="Fitness")
plt.subplot(2,3,5)
sns.boxplot(data,x="MaritalStatus",y="Income")
plt.subplot(2,3,6)
sns.boxplot(data,x="MaritalStatus",y="Miles")
plt.show()

# %% [markdown]
# education level, usage and fitness of both single and partnered are almost same
#
# partnered have higher income as compare to single
#
# partnered have higher variablitiy in income and walks as compare to single

# %%
# bivariate analysis of all category columns with product column
plt.figure(figsize=(15, 8))
plt.subplot(1,2,1)
sns.countplot(data,x="Product",hue="Gender")
plt.subplot(1,2,2)
sns.countplot(data,x="Product",hue="MaritalStatus")
plt.show()

# %% [markdown]
# female prefer kp781 less as compare to male
#
# partnered buyers are more as compare to single

# %%
# bivariate analysis of all category columns with product column
plt.figure(figsize=(15, 8))
plt.subplot(1,2,1)
sns.countplot(data,x="Gender",hue="Product")
plt.subplot(1,2,2)
sns.countplot(data,x="MaritalStatus",hue="Product")
plt.show()

# %% [markdown]
# majority of female prefer to buy kp281 and kp781
#
# KP281 and kp481 are also most prefered by single and partnered

# %% [markdown]
# Multivariate Analysis

# %%
# bivariate analysis of all numeric columns with marital status and product column
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.boxplot(data,x="MaritalStatus",y="Age",hue="Product")
plt.subplot(2,3,2)
sns.boxplot(data,x="MaritalStatus",y="Education",hue="Product")
plt.subplot(2,3,3)
sns.boxplot(data,x="MaritalStatus",y="Usage",hue="Product")
plt.subplot(2,3,4)
sns.boxplot(data,x="MaritalStatus",y="Fitness",hue="Product")
plt.subplot(2,3,5)
sns.boxplot(data,x="MaritalStatus",y="Income",hue="Product")
plt.subplot(2,3,6)
sns.boxplot(data,x="MaritalStatus",y="Miles",hue="Product")
plt.show()

# %%
# bivariate analysis of all numeric columns with gemder and product column
plt.figure(figsize=(20, 8))
plt.subplot(2,3,1)
sns.boxplot(data,x="Gender",y="Age",hue="Product")
plt.subplot(2,3,2)
sns.boxplot(data,x="Gender",y="Education",hue="Product")
plt.subplot(2,3,3)
sns.boxplot(data,x="Gender",y="Usage",hue="Product")
plt.subplot(2,3,4)
sns.boxplot(data,x="Gender",y="Fitness",hue="Product")
plt.subplot(2,3,5)
sns.boxplot(data,x="Gender",y="Income",hue="Product")
plt.subplot(2,3,6)
sns.boxplot(data,x="Gender",y="Miles",hue="Product")
plt.show()

# %%
sns.scatterplot(x=data["Income"], y=data["Age"], hue=data["Product"])
plt.show()

# %% [markdown]
# majority of the data lies 24 to 34 age group and 40000 to 60000 income

# %% [markdown]
# # **Representing the Probability**

# %%
# Find the marginal probability USING CROSSTAB

# %%
pd.crosstab(index=data['Gender'], columns=data['Product'],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %%
pd.crosstab(index=data['Gender'], columns=data['Product'],margins=True, normalize=True)*100
# Out:
# Product      KP281      KP481      KP781         All
# Gender
# Female   22.222222  16.111111   3.888889   42.222222
# Male     22.222222  17.222222  18.333333   57.777778
# All      44.444444  33.333333  22.222222  100.000000

# %%
pd.crosstab(index=data['MaritalStatus'], columns=data['Product'],margins=True)
# Out:
# Product        KP281  KP481  KP781  All
# MaritalStatus
# Partnered         48     36     23  107
# Single            32     24     17   73
# All               80     60     40  180

# %%
pd.crosstab(index=data['MaritalStatus'], columns=data['Product'],margins=True, normalize=True)*100
# Out:
# Product            KP281      KP481      KP781         All
# MaritalStatus
# Partnered      26.666667  20.000000  12.777778   59.444444
# Single         17.777778  13.333333   9.444444   40.555556
# All            44.444444  33.333333  22.222222  100.000000

# %%
# FINDING MARGINAL Probability USING MELT FUNCTION
data1 = data[['Product', 'Gender', 'MaritalStatus']].melt()
data1.groupby(['variable', 'value'])[['value']].count() / len(data)
# Out:
#                             value
# variable      value
# Gender        Female     0.422222
#               Male       0.577778
# MaritalStatus Partnered  0.594444
#               Single     0.405556
# Product       KP281      0.444444
#               KP481      0.333333
#               KP781      0.222222

# %% [markdown]
# MARGINAL PROBABILITY
#
# *57.78% of the people are male user
#
# *59.44% of the people are Partnered
#
# *44.44% uses KP281
#
# *33.33% uses KP481
#
# *22.22% uses KP781

# %% [markdown]
# CONDITIONAL PROBABILITY

# %%
pd.crosstab(index=data['Gender'], columns=data['Product'],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %% [markdown]
# CONDITIONAL PROBABILITY
#
# *Probablity of KP281 given that a customer is male
#
# ANS= 40/104
#
# *Probablity of males given the product is KP781
#
# ANS=33/40
#
# *probability OF KP481 given that a customer is female
#
# ANS= 29/76

# %% [markdown]
# # **Check the correlation among different COLUMNS**

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data1=data.drop(["Product","Gender","MaritalStatus"],axis=1)

# %%
data1.head()
# Out:
#    Age  Education  Usage  Fitness  Income  Miles
# 0   18         14      3        4   29562    112
# 1   19         15      2        3   31836     75
# 2   19         14      4        3   30699     66
# 3   19         12      3        3   32973     85
# 4   20         13      4        2   35247     47

# %%
data1.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(data1.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# As you can see in the Heatmap There is highest corelation between:
#
# Fitness and Miles (higher the miles more the fitness)
#
# Usage and Miles (higher the miles more of usage)
#
# Fitness and Usage (higher the usage more of fitness)
#
# Income and Education (higher the Education more of Income)
#
# Also we can see less corelation between:
#
# Age and Usage
#
# Age and Miles
#
# Age and Fitness

# %% [markdown]
# # **Analysis by age**

# %%
data["Age"].min()
# Out:
# 18

# %%
data["Age"].max()
# Out:
# 50

# %%
# create age bins
bin=[1,18,22,27,33,38,43,50]
label=["<18","18-22","23-27","28-33","34-38","39-43","44-50"]
data["age_bins"]=pd.cut(data["Age"],bins=bin,labels=label)
data["age_bins"]
# Out:
# 0        <18
# 1      18-22
# 2      18-22
# 3      18-22
# 4      18-22
#        ...
# 175    39-43
# 176    39-43
# 177    44-50
# 178    44-50
# 179    44-50
# Name: age_bins, Length: 180, dtype: category
# Categories (7, object): ['<18' < '18-22' < '23-27' < '28-33' < '34-38' < '39-43' < '44-50']

# %%
# which age group bought most products
sns.histplot(data,x="age_bins",kde=True)
plt.show()

# %%
#total value per age group
data_agebins=data["age_bins"].value_counts(ascending =False).reset_index()

# %%
# rename the count column to total product columns
data_agebins.rename(columns=({"count":"Total_products"}),inplace =True)

# %%
data_agebins
# Out:
#   age_bins  Total_products
# 0    23-27              74
# 1    28-33              40
# 2    34-38              24
# 3    18-22              23
# 4    39-43               9
# 5    44-50               9
# 6      <18               1

# %%
# percentage of product from top age group
top_age=["23-27","28-33","34-38","18-22"]
#count of products brought by top age group
sum_of_top=data_agebins[data_agebins["age_bins"].isin(top_age)]["Total_products"].sum()
# total product sold
total_pro=data_agebins["Total_products"].sum()
# percentage of product brought by top age
per_of_top=sum_of_top/total_pro*100
per_of_top
# Out:
# 89.44444444444444

# %% [markdown]
# **90% products brought by agegroup of 18-38**

# %%
# percentage of product from top age group
top_age=["23-27","28-33"]
#count of products brought by top age group
sum_of_top=data_agebins[data_agebins["age_bins"].isin(top_age)]["Total_products"].sum()
# total product sold
total_pro=data_agebins["Total_products"].sum()
# percentage of product brought by top age group
per_of_top=sum_of_top/total_pro*100
per_of_top
# Out:
# 63.33333333333333

# %% [markdown]
# **64% products brought by agegroup of 23-33**

# %%
# which age group brought which product
pro_data=data.groupby(["age_bins","Product"])["Product"].count()
pro_data
# Out:
# age_bins  Product
# <18       KP281       1
#           KP481       0
#           KP781       0
# 18-22     KP281      13
#           KP481       7
#           KP781       3
# 23-27     KP281      30
#           KP481      25
#           KP781      19
# 28-33     KP281      17
#           KP481      13
#           KP781      10
# 34-38     KP281      11
#           KP481      10
#           KP781       3
# 39-43     KP281       4
#           KP481       3
#           KP781       2
# 44-50     KP281       4
#           KP481       2
#           KP781       3
# Name: Product, dtype: int64

# %%
KP781
# Out:
# 40

# %%
KP481
# Out:
# 60

# %%
KP281
# Out:
# 80

# %% [markdown]
# **44% sales by KP281 ,33% sales by KP481 22% sales by KP781**

# %%
# find total kp781 in our data
KP781=data[data["Product"]=="KP781"]["Product"].count()
# find total kp781 for age group 23-27 in our data
kp781_23=data.loc[(data['age_bins'] == "23-27") & (data['Product'] =="KP781")]["Product"].count()
# find total kp781 for age group 28-33 in our data
kp781_33=data.loc[(data['age_bins'] == "28-33") & (data['Product'] =="KP781")]["Product"].count()
# total kp781 for agre group 23-33
kp781_23_33=kp781_23+kp781_33
# percentage of kp781 out of total kp781
kp781_23_33/KP781*100
# Out:
# 72.5

# %% [markdown]
# **73% of KP781 were brought by age-group 23-33**

# %%
# find total kp781 in our data
KP481=data[data["Product"]=="KP481"]["Product"].count()
# find total KP481 for age group 23-27 in our data
kp481_23=data.loc[(data['age_bins'] == "23-27") & (data['Product'] =="KP481")]["Product"].count()
# find total KP481 for age group 28-33 in our data
kp481_33=data.loc[(data['age_bins'] == "28-33") & (data['Product'] =="KP481")]["Product"].count()
# total kp481 for agre group 23-33
kp481_23_33=kp481_23+kp481_33
# percentage of kp481 out of total kp481
kp481_23_33/KP481*100
# Out:
# 63.33333333333333

# %% [markdown]
# **63% of KP481 were brought by age-group 23-33**

# %%
# find total kp281 in our data
KP281=data[data["Product"]=="KP281"]["Product"].count()
# find total KP281 for age group 23-27 in our data
kp281_23=data.loc[(data['age_bins'] == "23-27") & (data['Product'] =="KP281")]["Product"].count()
# find total KP281 for age group 28-33 in our data
kp281_33=data.loc[(data['age_bins'] == "28-33") & (data['Product'] =="KP281")]["Product"].count()
# total kp281 for agre group 23-33
kp281_23_33=kp281_23+kp281_33
# percentage of kp281 out of total kp481
kp281_23_33/KP281*100
# Out:
# 58.75

# %% [markdown]
# 59% of KP281 were brought by age-group 23-33

# %%
# which age group bought most products
sns.histplot(data,x="age_bins",hue="Product")
plt.show()

# %% [markdown]
# # **Analysis by gender**

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
# count total male from dataset
total_male=data[data["Gender"]=="Male"]["Gender"].count()
# count total female from dataset
total_female=data[data["Gender"]=="Female"]["Gender"].count()
# count total from dataset
total=data["Gender"].count()
total
# Out:
# 180

# %%
#perc of male
total_male/total*100
# Out:
# 57.77777777777777

# %%
#perc of male
total_female/total*100
# Out:
# 42.22222222222222

# %%
# visual representation of gender distribution
sns.countplot(data,x="Gender")
plt.show()

# %% [markdown]
# **58% are male and 42% are female buyers in our data**

# %%
# create separate dataset for female and male
male_data=data[data["Gender"]=="Male"]
female_data=data[data["Gender"]=="Female"]

# %%
total_male=len(male_data)
total_female=len(female_data)

# %%
male_data.head()
# Out:
#   Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles  \
# 0   KP281   18   Male         14        Single      3        4   29562    112
# 1   KP281   19   Male         15        Single      2        3   31836     75
# 3   KP281   19   Male         12        Single      3        3   32973     85
# 4   KP281   20   Male         13     Partnered      4        2   35247     47
# 7   KP281   21   Male         13        Single      3        3   32973     85
#
#   age_bins
# 0      <18
# 1    18-22
# 3    18-22
# 4    18-22
# 7    18-22

# %%
# group male data by product
group_male=male_data.groupby("Product")["Gender"].count()
group_male
# Out:
# Product
# KP281    40
# KP481    31
# KP781    33
# Name: Gender, dtype: int64

# %%
# group female data by product
group_female=female_data.groupby("Product")["Gender"].count()
group_female
# Out:
# Product
# KP281    40
# KP481    29
# KP781     7
# Name: Gender, dtype: int64

# %%
# count each product type for male data
kp781_male=male_data[male_data["Product"]=="KP781"]["Product"].count()
kp481_male=male_data[male_data["Product"]=="KP481"]["Product"].count()
kp281_male=male_data[male_data["Product"]=="KP281"]["Product"].count()

# %%
kp781_male/total_male*100
# Out:
# 31.73076923076923

# %%
kp481_male/total_male*100
# Out:
# 29.807692307692307

# %%
kp281_male/total_male*100
# Out:
# 38.46153846153847

# %%
sns.countplot(male_data,x="Product")
plt.show()

# %% [markdown]
# **kp 281 is more prefered by male around 39% male brought kp281**

# %%
# count each product type for male data
kp781_female=female_data[female_data["Product"]=="KP781"]["Product"].count()
kp481_female=female_data[female_data["Product"]=="KP481"]["Product"].count()
kp281_female=female_data[female_data["Product"]=="KP281"]["Product"].count()

# %%
kp781_female/total_female*100
# Out:
# 9.210526315789473

# %%
kp481_female/total_female*100
# Out:
# 38.15789473684211

# %%
kp281_female/total_female*100
# Out:
# 52.63157894736842

# %%
sns.countplot(female_data,x="Product")
plt.show()

# %% [markdown]
# **kp 281 is also more prefered by female around 53% female brought kp281 and female have least interested in buying kp781 only 9%**

# %%
# create separate data for every product type
kp281=data[data["Product"]=="KP281"]
kp481=data[data["Product"]=="KP481"]
kp781=data[data["Product"]=="KP781"]

# %%
len(kp281)
# Out:
# 80

# %%
len(kp481)
# Out:
# 60

# %%
len(kp781)
# Out:
# 40

# %%
# countof male that brought kp281
kp281[kp281["Gender"]=="Male"]["Gender"].count()
# Out:
# 40

# %%
# countof female that brought kp281
kp281[kp281["Gender"]=="Female"]["Gender"].count()
# Out:
# 40

# %%
# countof male that brought kp481
kp481[kp481["Gender"]=="Male"]["Gender"].count()
# Out:
# 31

# %%
# countof female that brought kp481
kp481[kp481["Gender"]=="Female"]["Gender"].count()
# Out:
# 29

# %%
# countof male that brought kp781
kp781[kp781["Gender"]=="Male"]["Gender"].count()
# Out:
# 33

# %%
# countof female that brought kp781
kp781[kp781["Gender"]=="Female"]["Gender"].count()
# Out:
# 7

# %%
# percentage of male brought diff product
male_kp281=kp281[kp281["Gender"]=="Male"]["Gender"].count()/len(kp281)*100
male_kp481=kp481[kp481["Gender"]=="Male"]["Gender"].count()/len(kp481)*100
male_kp781=kp781[kp781["Gender"]=="Male"]["Gender"].count()/len(kp781)*100

# %%
male_kp281
# Out:
# 50.0

# %%
male_kp481
# Out:
# 51.66666666666667

# %%
male_kp781
# Out:
# 82.5

# %%
female_kp281=kp281[kp281["Gender"]=="Female"]["Gender"].count()/len(kp281)*100
female_kp481=kp481[kp481["Gender"]=="Female"]["Gender"].count()/len(kp481)*100
female_kp781=kp781[kp781["Gender"]=="Female"]["Gender"].count()/len(kp781)*100

# %%
female_kp281
# Out:
# 50.0

# %%
female_kp481
# Out:
# 48.333333333333336

# %%
female_kp781
# Out:
# 17.5

# %%
sns.countplot(data,x="Product",hue="Gender")
plt.show()

# %% [markdown]
# KP281 male and female buyer are 50-50%.
#
# KP481 male and female buyer are almost 50% where male buyers are 52% and female buyers are 48%.
#
# KP781 buyerys are moslty male around 83% buyers are male

# %% [markdown]
# # **ANalysis based on education**

# %%
data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles', 'age_bins'],
#       dtype='object')

# %%
# counts of education in our dataset
data["Education"].value_counts()
# Out:
# Education
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: count, dtype: int64

# %%
data["Education"].unique()
# Out:
# array([14, 15, 12, 13, 16, 18, 20, 21])

# %%
len(data["Education"].unique())
# Out:
# 8

# %%
# count buyer have education 14 to 18
edu_14=data[data["Education"]==14]["Product"].count()
edu_15=data[data["Education"]==15]["Product"].count()
edu_16=data[data["Education"]==16]["Product"].count()
edu_18=data[data["Education"]==18]["Product"].count()
edu_14_to_18=(edu_14)+(edu_15)+(edu_16)+(edu_18)

# %%
edu_14_to_18/total*100
# Out:
# 93.33333333333333

# %%
edu_14_to_16=(edu_14)+(edu_15)+(edu_16)
edu_14_to_16/total*100
# Out:
# 80.55555555555556

# %%
sns.countplot(data,x="Education")
plt.show()

# %% [markdown]
# **93% buyers have education between 14 to 18 years and 81% of them having 14 to 16**

# %%
# create separate dataset for education 14 to 16
buyer_edu_14_to_16=data[(data["Education"]>=14) & (data["Education"]<=16) ]

# %%
len(buyer_edu_14_to_16)
# Out:
# 145

# %%
# creater product wise dataset having education 14 to 16
kp281_14_to_16=buyer_edu_14_to_16[buyer_edu_14_to_16["Product"]=="KP281"]["Product"].count()
kp481_14_to_16=buyer_edu_14_to_16[buyer_edu_14_to_16["Product"]=="KP481"]["Product"].count()
kp781_14_to_16=buyer_edu_14_to_16[buyer_edu_14_to_16["Product"]=="KP781"]["Product"].count()

# %%
kp281_14_to_16/len(buyer_edu_14_to_16)*100
# Out:
# 50.3448275862069

# %%
kp481_14_to_16/len(buyer_edu_14_to_16)*100
# Out:
# 37.93103448275862

# %%
kp781_14_to_16/len(buyer_edu_14_to_16)*100
# Out:
# 11.724137931034482

# %%
sns.countplot(buyer_edu_14_to_16,x="Product")
plt.show()

# %% [markdown]
# **50% buyer out of total buyers having education between 14 to 16 years prefer kp281  and these buyers are 80% of the total buyers**

# %%
 # create dataset for each product type
Kp281=data[data["Product"]=="KP281"]
Kp481=data[data["Product"]=="KP481"]
Kp781=data[data["Product"]=="KP781"]

# %%
len(Kp281)
# Out:
# 80

# %%
len(Kp481)
# Out:
# 60

# %%
len(Kp781)
# Out:
# 40

# %%
Kp281["Education"].value_counts()
# Out:
# Education
# 16    39
# 14    30
# 15     4
# 13     3
# 12     2
# 18     2
# Name: count, dtype: int64

# %%
Kp481["Education"].value_counts()
# Out:
# Education
# 16    31
# 14    23
# 13     2
# 18     2
# 12     1
# 15     1
# Name: count, dtype: int64

# %%
Kp781["Education"].value_counts()
# Out:
# Education
# 18    19
# 16    15
# 21     3
# 14     2
# 20     1
# Name: count, dtype: int64

# %%
sns.countplot(Kp281,x="Education")
plt.show()

# %%
sns.countplot(Kp481,x="Education")
plt.show()

# %%
sns.countplot(Kp781,x="Education")
plt.show()

# %%
kp_281_14_to_16=len(kp281[(Kp281["Education"]>=14) & (Kp281["Education"]<=16)])
kp_481_14_to_16=len(kp481[(Kp481["Education"]>=14) & (Kp481["Education"]<=16)])
kp_781_16_to_18=len(kp781[Kp781["Education"]>=16])

# %%
kp_281_14_to_16/len(Kp281)*100
# Out:
# 91.25

# %%
kp_481_14_to_16/len(Kp481)*100
# Out:
# 91.66666666666666

# %%
kp_781_16_to_18/len(Kp781)*100
# Out:
# 95.0

# %%
# counts of education in our dataset
data["Education"].value_counts()
# Out:
# Education
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: count, dtype: int64

# %%
sns.countplot(data,x="Education",hue="Product")
plt.show()

# %% [markdown]
# 91% buyer for kp281 having education between 14 to 16.
#
# 92% buyer for kp481 having education between 14 to 16.
#
# 95% buyer for kp781 having education greater than 16.

# %%
sns.boxplot(data,y="Education",x="Product")
# Out:
# <Axes: xlabel='Product', ylabel='Education'>

# %% [markdown]
# # **ANalysis based on marital status**

# %%
data["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
sns.countplot(data,x="MaritalStatus")
plt.show()

# %%
# separate data from marital status
part=data[data["MaritalStatus"]=="Partnered"]["MaritalStatus"].count()
sing=data[data["MaritalStatus"]=="Single"]["MaritalStatus"].count()

# %%
part
# Out:
# 107

# %%
sing
# Out:
# 73

# %%
per_part=part/total*100
per_sing=sing/total*100

# %%
per_part
# Out:
# 59.44444444444444

# %%
per_sing
# Out:
# 40.55555555555556

# %% [markdown]
# **59% buyers are Partnered and 41% are single**

# %%
partner=data[data["MaritalStatus"]=="Partnered"]
single=data[data["MaritalStatus"]=="Single"]

# %%
sns.countplot(partner,x="Product")
plt.show()

# %%
partner["Product"].value_counts()
# Out:
# Product
# KP281    48
# KP481    36
# KP781    23
# Name: count, dtype: int64

# %%
single["Product"].value_counts()
# Out:
# Product
# KP281    32
# KP481    24
# KP781    17
# Name: count, dtype: int64

# %%
p_KP281=partner[partner["Product"]=="KP281"]
p_KP481=partner[partner["Product"]=="KP481"]
p_KP781=partner[partner["Product"]=="KP781"]

# %%
s_KP281=single[single["Product"]=="KP281"]
s_KP481=single[single["Product"]=="KP481"]
s_KP781=single[single["Product"]=="KP781"]

# %%
len(p_KP281)/len(partner)*100
# Out:
# 44.85981308411215

# %%
len(p_KP481)/len(partner)*100
# Out:
# 33.64485981308411

# %%
len(p_KP781)/len(partner)*100
# Out:
# 21.49532710280374

# %%
len(s_KP281)/len(single)*100
# Out:
# 43.83561643835616

# %%
len(s_KP481)/len(single)*100
# Out:
# 32.87671232876712

# %%
len(s_KP781)/len(single)*100
# Out:
# 23.28767123287671

# %% [markdown]
# 59% buyers are Partnered and 41% are single.
#
# out of 59% partnered 45% preefer kp281 ,34% prefer kp481 and 21% prefer kp781.
#
# out of 41% partnered 44% preefer kp281 ,33% prefer kp481 and 23% prefer kp781.

# %%
kp281=data[data["Product"]=="KP281"]
kp481=data[data["Product"]=="KP481"]
kp781=data[data["Product"]=="KP781"]

# %%
kp281["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Partnered    48
# Single       32
# Name: count, dtype: int64

# %%
kp481["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Partnered    36
# Single       24
# Name: count, dtype: int64

# %%
kp781["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Partnered    23
# Single       17
# Name: count, dtype: int64

# %%
len(kp281)
# Out:
# 80

# %%
len(kp481)
# Out:
# 60

# %%
len(kp781)
# Out:
# 40

# %%
len(kp281[kp281["MaritalStatus"]=="Partnered"])/len(kp281)*100
# Out:
# 60.0

# %%
len(kp281[kp281["MaritalStatus"]=="Single"])/len(kp281)*100
# Out:
# 40.0

# %%
len(kp481[kp481["MaritalStatus"]=="Partnered"])/len(kp481)*100
# Out:
# 60.0

# %%
len(kp481[kp481["MaritalStatus"]=="Single"])/len(kp481)*100
# Out:
# 40.0

# %%
len(kp781[kp781["MaritalStatus"]=="Partnered"])/len(kp781)*100
# Out:
# 57.49999999999999

# %%
len(kp781[kp781["MaritalStatus"]=="Single"])/len(kp781)*100
# Out:
# 42.5

# %%
sns.countplot(data,x="Product",hue="MaritalStatus")
plt.show()

# %% [markdown]
# IN KP281  product 60% of buyers are partnered and rest 40% are single.
#
# IN KP481  product 60% of buyers are partnered and rest 40% are single.
#
# IN KP781  product 58% of buyers are partnered and rest 42% are single.

# %% [markdown]
# # **Analysis based on income**

# %%
data["Income"].unique()
# Out:
# array([ 29562,  31836,  30699,  32973,  35247,  37521,  36384,  38658,
#         40932,  34110,  39795,  42069,  44343,  45480,  46617,  48891,
#         53439,  43206,  52302,  51165,  50028,  54576,  68220,  55713,
#         60261,  67083,  56850,  59124,  61398,  57987,  64809,  47754,
#         65220,  62535,  48658,  54781,  48556,  58516,  53536,  61006,
#         57271,  52291,  49801,  62251,  64741,  70966,  75946,  74701,
#         69721,  83416,  88396,  90886,  92131,  77191,  52290,  85906,
#        103336,  99601,  89641,  95866, 104581,  95508])

# %%
data["Income"].min()
# Out:
# 29562

# %%
data["Income"].max()
# Out:
# 104581

# %%
bin=[29000,39000,49000,59000,69000,79000,89000,100000]
label=["29-39","40-49","50-59","60-69","70-79","80-89","90-100"]
data["income_bins"]=pd.cut(data["Income"],bins=bin,labels=label)

# %%
sns.countplot(data,x="income_bins")
plt.show()

# %%
label=["29-39","40-49","50-59","60-69","70-79","80-89","90-100"]
two=data[data["income_bins"]=="29-39"]
four=data[data["income_bins"]=="40-49"]
fiv=data[data["income_bins"]=="50-59"]
six=data[data["income_bins"]=="60-69"]
sev=data[data["income_bins"]=="70-79"]
eight=data[data["income_bins"]=="80-89"]
nine=data[data["income_bins"]=="90-100"]

# %%
data["income_bins"].value_counts()
# Out:
# income_bins
# 50-59     54
# 40-49     51
# 29-39     30
# 60-69     21
# 90-100    11
# 70-79      5
# 80-89      5
# Name: count, dtype: int64

# %%
(len(two)/total*100) + (len(fiv)/total*100) +(len(four)/total*100) + (len(six)/total*100)
# Out:
# 86.66666666666667

# %%
(len(fiv)/total*100) +(len(four)/total*100)
# Out:
# 58.33333333333333

# %% [markdown]
# **87% buyers are from  29000 to 70000 income group and 58% of them are from 40000 to 60000 income group**

# %%
kp281=data[data["Product"]=="KP281"]
kp481=data[data["Product"]=="KP481"]
kp781=data[data["Product"]=="KP781"]

# %%
kp281["income_bins"].value_counts()
# Out:
# income_bins
# 40-49     27
# 50-59     25
# 29-39     21
# 60-69      7
# 70-79      0
# 80-89      0
# 90-100     0
# Name: count, dtype: int64

# %%
sns.countplot(kp281,x="income_bins")
# Out:
# <Axes: xlabel='income_bins', ylabel='count'>

# %%
kp481["income_bins"].value_counts()
# Out:
# income_bins
# 40-49     21
# 50-59     21
# 29-39      9
# 60-69      9
# 70-79      0
# 80-89      0
# 90-100     0
# Name: count, dtype: int64

# %%
sns.countplot(kp481,x="income_bins")
# Out:
# <Axes: xlabel='income_bins', ylabel='count'>

# %%
kp781["income_bins"].value_counts()
# Out:
# income_bins
# 90-100    11
# 50-59      8
# 60-69      5
# 70-79      5
# 80-89      5
# 40-49      3
# 29-39      0
# Name: count, dtype: int64

# %%
sns.countplot(kp781,x="income_bins")
# Out:
# <Axes: xlabel='income_bins', ylabel='count'>

# %%
sns.countplot(data,x="income_bins",hue="Product")
# Out:
# <Axes: xlabel='income_bins', ylabel='count'>

# %%
sns.boxplot(data,x="Product",y="Income")
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %% [markdown]
# kp281 and kp481 is prefered by low or mid income groups.
#
# kp781 is prefered by high income groups

# %% [markdown]
# # **Analysis based on miles**

# %%
data.groupby("Product")["Miles"].sum()
# Out:
# Product
# KP281    6623
# KP481    5276
# KP781    6676
# Name: Miles, dtype: int64

# %%
data.groupby("Product")["Miles"].mean()
# Out:
# Product
# KP281     82.787500
# KP481     87.933333
# KP781    166.900000
# Name: Miles, dtype: float64

# %%
sns.boxplot(x=data["Product"],y=data["Miles"])
plt.show()

# %% [markdown]
# **average number of miles the customer walks/runs each week is higher who using Kp781**

# %% [markdown]
# # **Analysis based on fitness**

# %%
data["Fitness"].value_counts()
# Out:
# Fitness
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: count, dtype: int64

# %%
len(data[data["Fitness"]>=3])/len(data)*100
# Out:
# 84.44444444444444

# %% [markdown]
# 85% user have fitness level above 3

# %%
sns.countplot(data,x="Fitness")
plt.show()

# %%
kp281=data[data["Product"]=="KP281"]
kp481=data[data["Product"]=="KP481"]
kp781=data[data["Product"]=="KP781"]

# %%
kp281["Fitness"].value_counts()
# Out:
# Fitness
# 3    54
# 2    14
# 4     9
# 5     2
# 1     1
# Name: count, dtype: int64

# %%
len(kp281[kp281["Fitness"]<=3])/len(kp281)*100
# Out:
# 86.25

# %% [markdown]
# **86% of users who use kp281 there fitness level are less than 3**

# %%
kp481["Fitness"].value_counts()
# Out:
# Fitness
# 3    39
# 2    12
# 4     8
# 1     1
# Name: count, dtype: int64

# %%
len(kp481[kp481["Fitness"]<=3])/len(kp481)*100
# Out:
# 86.66666666666667

# %% [markdown]
# 87% of users who use kp481 there fitness level are less than 3

# %%
kp781["Fitness"].value_counts()
# Out:
# Fitness
# 5    29
# 4     7
# 3     4
# Name: count, dtype: int64

# %%
len(kp781[kp781["Fitness"]>=4])/len(kp781)*100
# Out:
# 90.0

# %% [markdown]
# 90% of users who use kp781 there fitness level are above 4

# %%
sns.boxplot(x=data["Product"], y=data["Fitness"])
# Out:
# <Axes: xlabel='Product', ylabel='Fitness'>

# %% [markdown]
# 85% of total user have fitness level above 3
#
# 86% of users who use kp281 there fitness level are less than 3.
#
# 87% of users who use kp481 there fitness level are less than 3.
#
# 90% of users who use kp781 there fitness level are above 4

# %% [markdown]
# # **Analysis bases on usage**

# %%
data["Usage"].unique()
# Out:
# array([3, 2, 4, 5, 6, 7])

# %%
data["Usage"].value_counts()
# Out:
# Usage
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: count, dtype: int64

# %%
len(data[data["Usage"]<=4])/len(data)*100
# Out:
# 85.55555555555556

# %% [markdown]
# **86% of total user have use the products less than 4 times a week**

# %%
sns.countplot(data,x="Usage")
plt.show()

# %%
kp281=data[data["Product"]=="KP281"]
kp481=data[data["Product"]=="KP481"]
kp781=data[data["Product"]=="KP781"]

# %%
kp281["Usage"].value_counts()
# Out:
# Usage
# 3    37
# 4    22
# 2    19
# 5     2
# Name: count, dtype: int64

# %%
kp481["Usage"].value_counts()
# Out:
# Usage
# 3    31
# 2    14
# 4    12
# 5     3
# Name: count, dtype: int64

# %%
kp781["Usage"].value_counts()
# Out:
# Usage
# 4    18
# 5    12
# 6     7
# 7     2
# 3     1
# Name: count, dtype: int64

# %%
sns.boxplot(x=data["Product"], y=data["Usage"])
# Out:
# <Axes: xlabel='Product', ylabel='Usage'>

# %%
sns.countplot(data,x="Usage",hue="Product")
# Out:
# <Axes: xlabel='Usage', ylabel='count'>

# %% [markdown]
# 98% user of kp281 use the treadmil less than 4 times a week
#
# 95% user of kp481 use the treadmil less than 4 times a week
#
# 98% user of kp781 use the treadmil more than 4 times a week

# %% [markdown]
# # **Insights**

# %%
 '''* There are three unique products: 'KP281', 'KP481', and 'KP781', where 44% of users use KP281, 33% use KP481, and 22% use KP781.
    * The majority of the product is purchased in the age group of 24 to 32.
    * The majority of people with a total education of 16 years are buying this product. People mostly use this product 3 to 4 days a week.
    * According to the data, the average fitness rating of the people is 3.
    * KP281 is the most purchased product (44.44% use KP281).
    * There are more males buying the product than females (57.78% of the people are male users), and kp281 is more preferred by males and females.
    * More partnered people are in the data (59.44% of the people are partnered).
    * The majority of the data lies in the 22–34 age group (64% of products brought by the age group of 23–33). and 40000 to 55000 income range
    * People with education above 16 tend to buy KP781.
    * People running or walking over 120 miles per week are using KP781.
    * People with fitness levels greater than four use KP781.
    * Females prefer kp781 less as compared to males.
    * The correlation between fitness and miles is high (the higher the miles, the greater the fitness).
    * The correlation between usage and miles is high (the higher the miles, the more usage).
    * The correlation between fitness and usage is high (the higher the usage, the more fitness).
    * People who are using the product more than 4 days a week have the highest possibility that the product is KP781.
    * 90% of people who use kp781 have a fitness level above 4.'''
# Out:
# "* There are three unique products: 'KP281', 'KP481', and 'KP781', where 44% of users use KP281, 33% use KP481, and 22% use KP781.\n   * The majority of the product is purchased in the age group of 24 to 32.\n   * The majority of people with a total education of 16 years are buying this product. People mostly use this product 3 to 4 days a week.\n   * According to the data, the average fitness rating of the people is 3.\n   * KP281 is the most purchased product (44.44% use KP281).\n   * There are more males buying the product than females (57.78% of the people are male users), and kp281 is more preferred by males and females.\n   * More partnered people are in the data (59.44% of the people are partnered).\n   * The majority of the data lies in the 22–34 age group (64% of products brought by the age group of 23–33). and 40000 to 55000 income range\n   * People with education above 16 tend to buy KP781.\n   * People running or walking over 120 miles per week are using KP781.\n   * Peo
# ...

# %% [markdown]
# # **Recommendations**

# %%
'''* Focus marketing efforts on the age group of 22 to 34, as they are the majority purchasers of the product.
   * Partnered people are more likely to buy this product, so company can run a campaign to attract more single people.
   * Aerofit can target people with Income above 60000 , education above 16 years,and who exercise more then 4 days a week they are more likely to buy advance feature products(KP781) according to data
   * People who are using KP481 and have Income above 55000 can be recommend to upgrage to KP781.
   * As Partnered people more likely buys this product, Aerofit can also sell couple or family oriented fitness products eg. fitness watches
   * Aerofit can provide attractive offers or discounts to female customers
   * Develop specific messaging to encourage female customers to consider the benefits of KP781, emphasizing its fitness-related advantages'''
# Out:
# '* Focus marketing efforts on the age group of 22 to 34, as they are the majority purchasers of the product.\n   * Partnered people are more likely to buy this product, so company can run a campaign to attract more single people.\n   * Aerofit can target people with Income above 60000 , education above 16 years,and who exercise more then 4 days a week they are more likely to buy advance feature products(KP781) according to data\n   * People who are using KP481 and have Income above 55000 can be recommend to upgrage to KP781.\n   * As Partnered people more likely buys this product, Aerofit can also sell couple or family oriented fitness products eg. fitness watches \n   * Aerofit can provide attractive offers or discounts to female customers\n   * Develop specific messaging to encourage female customers to consider the benefits of KP781, emphasizing its fitness-related advantages'
